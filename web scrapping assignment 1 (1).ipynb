# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#answer 1
page=requests.get(r'https://www.imdb.com/list/ls056092300/')
page
# Out:
# <Response [403]>

# %%
#The page is not giving permission to access resourse.

# %%
#answer 2
page=requests.get(r'https://www.patreon.com/coreyms')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
first_title=soup.find('div', class_="sc-kDTinF kgeRcu")
first_title
#i am not able to understand which tag and which class has to pass to get the posts information from the page i need help here 
#tried everything

# %%
#answer 3

# %%
#i had completed all the questions but a security error occured and everything gone!

# %% [markdown]
# ![Screenshot%20%2819%29.png](attachment:Screenshot%20%2819%29.png)
